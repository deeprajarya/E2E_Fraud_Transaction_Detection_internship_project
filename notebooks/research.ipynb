# %%
import pandas as pd

# Read the CSV file into a DataFrame
path = "C:/iNeurOn_Projects/E2E_CCFD_new_version_13_01_2024/artifacts/test.csv"
df = pd.read_csv(path)

# Filter rows where the 'class' column is 1
filtered_df = df[df['Class'] == 1]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv('filtered_data.csv', index=False)

# %%
# Read the CSV file into a DataFrame
path = "C:/iNeurOn_Projects/E2E_CCFD_new_version_13_01_2024/notebooks/filtered_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#        Time         V1        V2         V3         V4        V5        V6  \
# 0  158638.0  -5.976119 -7.196980  -5.388316   5.104799  4.676533 -5.566870
# 1   17520.0  -5.268053  9.067613 -15.960728  10.296603 -4.708241 -3.395375
# 2   59669.0   0.326007  1.286638  -2.007181   2.419675 -1.532902 -1.432803
# 3   18690.0 -15.398845  7.472324 -19.026912  11.165526 -6.893856 -2.120937
# 4   14073.0  -4.153014  8.204797 -15.031714  10.330100 -3.994426 -3.250013
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  -4.291180  0.876531 -1.075478  ...  1.459369 -0.136262  0.848177 -0.269916
# 1 -11.161057  5.499963 -5.667376  ...  2.004110  0.191058  0.622928 -1.209264
# 2  -2.459530  0.617738 -1.125861  ...  0.556895  0.169776 -0.174357  0.308061
# 3 -14.913330 -0.721214 -7.175097  ... -2.444884  0.727495 -0.345078 -0.981749
# 4 -10.415698  4.620804 -5.711248  ...  1.976988  0.256510  0.485908 -1.198821
#
# ...

# %%
df.shape
# Out:
# (101, 31)
